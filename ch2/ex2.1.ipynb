# %% [markdown]
# # Exercise 2.1
#
# ![image.png](attachment:image.png)

# %%
a = 2.3
(6 * a + 42) / 3 ^(4.2 - 3.62)
# Out:
# [1] 29.50556

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
# #### 3. Using R, how would you calculate the square root of half of the average of the numbers 25.2, 15, 16.44, 15.3, and 18.6?

# %%
sqrt((25.2 + 15 + 16.44 + 15.3 + 18.6) / 5)
# Out:
# [1] 4.25535

# %% [markdown]
# #### 4. Find the natural log. of 0.3.

# %%
log(0.3)
# Out:
# [1] -1.203973

# %% [markdown]
# #### 5. Compute the exponential transform of your last answer.

# %%
exp(log(0.3))
# Out:
# [1] 0.3

# %% [markdown]
# #### 6. Identify R’s representation of −0.00000000423546322 when printing this number to the console.

# %%
−0.00000000423546322
# Out:
# [1] -4.235463e-09
